# %% [markdown]
# # Example behavior session
# The following example shows how to access behavioral data for a given mouse across sessions
#
# We will first install allensdk into your environment by running the appropriate commands below.

# %% [markdown]
# ## Install AllenSDK into your local environment

# %% [markdown]
# You can install AllenSDK with:

# %%
# !pip install allensdk
# Out:
# Requirement already satisfied: allensdk in c:\users\marinag\documents\code\allensdk (2.15.2)
# Requirement already satisfied: psycopg2-binary in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.9.5)
# Requirement already satisfied: hdmf<=3.4.7 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.4.7)
# Requirement already satisfied: h5py in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.7.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.5.2)
# Requirement already satisfied: numpy in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.21.5)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.4.4)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.1.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.9.1)
# Requirement already satisfied: six<2.0.0,>=1.9.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.16.0)
# Requirement already satisfied: pynrrd<1.0.0,>=0.2.1 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.4.3)
# Requirement already satisfied: future<1.0.0,>=0.14.3 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.18.2)
# Requirement already satisfied: requests<3.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.28.1)
# Requirement already satisfied: requests-toolbelt<1.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.10.1)
# Requirement already satisfied: simplejson<4.0.0,>=3.10.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.18.0)
# Requirement already satisfied: scikit-image>=0.14.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.19.2)
# Requirement already satisfied: scikit-build<1.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.16.2)
# Requirement already satisfied: statsmodels in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.13.5)
# Requirement already satisfied: simpleitk<3.0.0,>=2.0.2 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.2.0)
# Requirement already satisfied: argschema<4.0.0,>=3.0.1 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.0.4)
# Requirement already satisfied: glymur==0.8.19 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.8.19)
# Requirement already satisfied: xarray in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2022.11.0)
# Requirement already satisfied: pynwb in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.2.0)
# Requirement already satisfied: tables in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.6.1)
# Requirement already satisfied: seaborn<1.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.11.2)
# Requirement already satisfied: aiohttp==3.7.4 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.7.4)
# Requirement already satisfied: nest_asyncio in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.5.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (4.64.1)
# Requirement already satisfied: ndx-events<=0.2.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.2.0)
# Requirement already satisfied: boto3==1.17.21 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.17.21)
# Requirement already satisfied: semver in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.13.0)
# Requirement already satisfied: cachetools<5.0.0,>=4.2.1 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (4.2.4)
# Requirement already satisfied: sqlalchemy in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.4.39)
# Requirement already satisfied: python-dateutil in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.8.2)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (3.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (4.3.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\marinag\anaconda3\lib\site-packages (from boto3==1.17.21->allensdk) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in c:\users\marinag\anaconda3\lib\site-packages (from boto3==1.17.21->allensdk) (0.3.7)
# Requirement already satisfied: botocore<1.21.0,>=1.20.21 in c:\users\marinag\anaconda3\lib\site-packages (from boto3==1.17.21->allensdk) (1.20.112)
# Requirement already satisfied: setuptools in c:\users\marinag\anaconda3\lib\site-packages (from glymur==0.8.19->allensdk) (63.4.1)
# Requirement already satisfied: marshmallow<4.0,>=3.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from argschema<4.0.0,>=3.0.1->allensdk) (3.19.0)
# Requirement already satisfied: pyyaml in c:\users\marinag\anaconda3\lib\site-packages (from argschema<4.0.0,>=3.0.1->allensdk) (6.0)
# Requirement already satisfied: ruamel.yaml<1,>=0.16 in c:\users\marinag\anaconda3\lib\site-packages (from hdmf<=3.4.7->allensdk) (0.17.21)
# Requirement already satisfied: jsonschema<5,>=2.6.0 in c:\users\marinag\anaconda3\lib\site-packages (from hdmf<=3.4.7->allensdk) (4.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marinag\anaconda3\lib\site-packages (from jinja2>=3.0.0->allensdk) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marinag\anaconda3\lib\site-packages (from pandas>=1.1.5->allensdk) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (2.0.4)
# Requirement already satisfied: distro in c:\users\marinag\anaconda3\lib\site-packages (from scikit-build<1.0.0->allensdk) (1.8.0)
# Requirement already satisfied: wheel>=0.32.0 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-build<1.0.0->allensdk) (0.37.1)
# Requirement already satisfied: networkx>=2.2 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (2.8.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (2.19.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (2021.7.2)
# Requirement already satisfied: colorama in c:\users\marinag\anaconda3\lib\site-packages (from tqdm>=4.27->allensdk) (0.4.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\marinag\anaconda3\lib\site-packages (from sqlalchemy->allensdk) (1.1.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\marinag\anaconda3\lib\site-packages (from statsmodels->allensdk) (0.5.2)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\marinag\anaconda3\lib\site-packages (from tables->allensdk) (2.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\marinag\anaconda3\lib\site-packages (from jsonschema<5,>=2.6.0->hdmf<=3.4.7->allensdk) (0.18.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in c:\users\marinag\anaconda3\lib\site-packages (from ruamel.yaml<1,>=0.16->hdmf<=3.4.7->allensdk) (0.2.7)

# %% [markdown]
# ## Install AllenSDK into your notebook environment

# %% [markdown]
# You can install AllenSDK into your notebook environment by executing the cell below.
#
# If using Google Colab, click on the RESTART RUNTIME button that appears at the end of the output when this cell is complete,. Note that running this cell will produce a long list of outputs and some error messages. Clicking RESTART RUNTIME at the end will resolve these issues.
# You can minimize the cell after you are done to hide the output.

# %%
# !pip install --upgrade pip
# !pip install allensdk
# Out:
# Requirement already satisfied: pip in c:\users\marinag\anaconda3\lib\site-packages (22.2.2)
# Collecting pip
#   Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 18.9 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# C:\Users\marinag\Anaconda3\python.exe -m pip install --upgrade pip
# Requirement already satisfied: allensdk in c:\users\marinag\documents\code\allensdk (2.15.2)
# Requirement already satisfied: psycopg2-binary in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.9.5)
# Requirement already satisfied: hdmf<=3.4.7 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.4.7)
# Requirement already satisfied: h5py in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.7.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.5.2)
# Requirement already satisfied: numpy in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.21.5)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.4.4)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.1.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.9.1)
# Requirement already satisfied: six<2.0.0,>=1.9.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.16.0)
# Requirement already satisfied: pynrrd<1.0.0,>=0.2.1 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.4.3)
# Requirement already satisfied: future<1.0.0,>=0.14.3 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.18.2)
# Requirement already satisfied: requests<3.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.28.1)
# Requirement already satisfied: requests-toolbelt<1.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.10.1)
# Requirement already satisfied: simplejson<4.0.0,>=3.10.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.18.0)
# Requirement already satisfied: scikit-image>=0.14.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.19.2)
# Requirement already satisfied: scikit-build<1.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.16.2)
# Requirement already satisfied: statsmodels in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.13.5)
# Requirement already satisfied: simpleitk<3.0.0,>=2.0.2 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.2.0)
# Requirement already satisfied: argschema<4.0.0,>=3.0.1 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.0.4)
# Requirement already satisfied: glymur==0.8.19 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.8.19)
# Requirement already satisfied: xarray in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2022.11.0)
# Requirement already satisfied: pynwb in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.2.0)
# Requirement already satisfied: tables in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.6.1)
# Requirement already satisfied: seaborn<1.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.11.2)
# Requirement already satisfied: aiohttp==3.7.4 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (3.7.4)
# Requirement already satisfied: nest_asyncio in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.5.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (4.64.1)
# Requirement already satisfied: ndx-events<=0.2.0 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (0.2.0)
# Requirement already satisfied: boto3==1.17.21 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.17.21)
# Requirement already satisfied: semver in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.13.0)
# Requirement already satisfied: cachetools<5.0.0,>=4.2.1 in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (4.2.4)
# Requirement already satisfied: sqlalchemy in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (1.4.39)
# Requirement already satisfied: python-dateutil in c:\users\marinag\anaconda3\lib\site-packages (from allensdk) (2.8.2)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (1.8.1)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\marinag\anaconda3\lib\site-packages (from aiohttp==3.7.4->allensdk) (4.3.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in c:\users\marinag\anaconda3\lib\site-packages (from boto3==1.17.21->allensdk) (0.3.7)
# Requirement already satisfied: botocore<1.21.0,>=1.20.21 in c:\users\marinag\anaconda3\lib\site-packages (from boto3==1.17.21->allensdk) (1.20.112)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\marinag\anaconda3\lib\site-packages (from boto3==1.17.21->allensdk) (0.10.0)
# Requirement already satisfied: setuptools in c:\users\marinag\anaconda3\lib\site-packages (from glymur==0.8.19->allensdk) (63.4.1)
# Requirement already satisfied: pyyaml in c:\users\marinag\anaconda3\lib\site-packages (from argschema<4.0.0,>=3.0.1->allensdk) (6.0)
# Requirement already satisfied: marshmallow<4.0,>=3.0.0 in c:\users\marinag\anaconda3\lib\site-packages (from argschema<4.0.0,>=3.0.1->allensdk) (3.19.0)
# Requirement already satisfied: jsonschema<5,>=2.6.0 in c:\users\marinag\anaconda3\lib\site-packages (from hdmf<=3.4.7->allensdk) (4.16.0)
# Requirement already satisfied: ruamel.yaml<1,>=0.16 in c:\users\marinag\anaconda3\lib\site-packages (from hdmf<=3.4.7->allensdk) (0.17.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marinag\anaconda3\lib\site-packages (from jinja2>=3.0.0->allensdk) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marinag\anaconda3\lib\site-packages (from matplotlib>=1.4.3->allensdk) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marinag\anaconda3\lib\site-packages (from pandas>=1.1.5->allensdk) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marinag\anaconda3\lib\site-packages (from requests<3.0.0->allensdk) (2023.5.7)
# Requirement already satisfied: distro in c:\users\marinag\anaconda3\lib\site-packages (from scikit-build<1.0.0->allensdk) (1.8.0)
# Requirement already satisfied: wheel>=0.32.0 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-build<1.0.0->allensdk) (0.37.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (2.19.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\marinag\anaconda3\lib\site-packages (from scikit-image>=0.14.0->allensdk) (2.8.4)
# Requirement already satisfied: colorama in c:\users\marinag\anaconda3\lib\site-packages (from tqdm>=4.27->allensdk) (0.4.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\marinag\anaconda3\lib\site-packages (from sqlalchemy->allensdk) (1.1.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\marinag\anaconda3\lib\site-packages (from statsmodels->allensdk) (0.5.2)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\marinag\anaconda3\lib\site-packages (from tables->allensdk) (2.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\marinag\anaconda3\lib\site-packages (from jsonschema<5,>=2.6.0->hdmf<=3.4.7->allensdk) (0.18.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in c:\users\marinag\anaconda3\lib\site-packages (from ruamel.yaml<1,>=0.16->hdmf<=3.4.7->allensdk) (0.2.7)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)

import allensdk.brain_observatory.behavior.behavior_project_cache as bpc

import allensdk
import pkg_resources
print('allensdk version 2.10.2 or higher is required, you have {} installed'.format(pkg_resources.get_distribution("allensdk").version))
# Out:
# allensdk version 2.10.2 or higher is required, you have 2.15.2 installed

# %%
# %matplotlib notebook

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## load cache, get behavior session table
# This will set a location on your local drive to cache NWB files.
# Then a table of all behavior sessions will be loaded.

# %%
# choose a location on your file system to cache NWB files as they are loaded:
output_dir = '/tmp/cache'

# %%
bc = bpc.VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=output_dir)
          
behavior_session_table = bc.get_behavior_session_table()
# Out:
# ophys_session_table.csv: 100%|█████████████████████████████████████████████████████| 227k/227k [00:00<00:00, 1.89MMB/s]
# behavior_session_table.csv: 100%|████████████████████████████████████████████████| 1.21M/1.21M [00:00<00:00, 4.50MMB/s]
# ophys_experiment_table.csv: 100%|██████████████████████████████████████████████████| 610k/610k [00:00<00:00, 3.84MMB/s]
# ophys_cells_table.csv: 100%|█████████████████████████████████████████████████████| 4.29M/4.29M [00:00<00:00, 7.19MMB/s]

# %% [markdown]
# ## view a sample of the behavior session table
# The `behavior_session_table` is a Pandas DataFrame with one row for every session and a collection of informative columns. We can view 10 randomly selected rows of the table using the Pandas `sample` command.
# It's important to note that this table contains every session, including sessions performed on a two-photon imaging rig (`session_type` starts with `OPHYS_`) and pre-imaging (aka 'training') sessions, (`session_type` starts with `TRAINING_`).

# %%
behavior_session_table.sample(10)
# Out:
#                     equipment_name  \
# behavior_session_id
# 871808378                   MESO.1
# 1086429747                  MESO.1
# 864236370               BEH.D-Box5
# 1079303677              BEH.D-Box2
# 844199766               BEH.B-Box2
# 1093804617              BEH.F-Box1
# 949480037               BEH.B-Box6
# 884756758               BEH.D-Box2
# 1065923469              BEH.D-Box4
# 1099395911              BEH.F-Box6
#
#                                                          full_genotype  \
# behavior_session_id
# 871808378                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 1086429747               Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 864236370                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 1079303677               Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 844199766            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 1093804617               Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 949480037                Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 884756758            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai94(TITL-G...
# 1065923469               Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 1099395911               Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
#
#                     mouse_id               reporter_line  \
# behavior_session_id
# 871808378             449653  Ai148(TIT2L-GC6f-ICL-tTA2)
# 1086429747            550603  Ai148(TIT2L-GC6f-ICL-tTA2)
# 864236370             453991  Ai148(TIT2L-GC6f-ICL-tTA2)
# 1079303677            550603  Ai148(TIT2L-GC6f-ICL-tTA2)
# 844199766             445270          Ai93(TITL-GCaMP6f)
# 1093804617            563234  Ai148(TIT2L-GC6f-ICL-tTA2)
# 949480037             476970  Ai148(TIT2L-GC6f-ICL-tTA2)
# 884756758             457766          Ai94(TITL-GCaMP6s)
# 1065923469            544965  Ai148(TIT2L-GC6f-ICL-tTA2)
# 1099395911            561443  Ai148(TIT2L-GC6f-ICL-tTA2)
#
#                                          driver_line sex  age_in_days  \
# behavior_session_id
# 871808378                             [Vip-IRES-Cre]   M        122.0
# 1086429747                            [Vip-IRES-Cre]   F        181.0
# 864236370                             [Vip-IRES-Cre]   M         88.0
# 1079303677                            [Vip-IRES-Cre]   F        153.0
# 844199766            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         88.0
# 1093804617                            [Vip-IRES-Cre]   F        121.0
# 949480037                             [Sst-IRES-Cre]   M        110.0
# 884756758            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        105.0
# 1065923469                            [Sst-IRES-Cre]   M        122.0
# 1099395911                            [Sst-IRES-Cre]   M        161.0
#
#                               cre_line indicator  session_number  \
# behavior_session_id
# 871808378                 Vip-IRES-Cre   GCaMP6f               3
# 1086429747                Vip-IRES-Cre   GCaMP6f               0
# 864236370                 Vip-IRES-Cre   GCaMP6f             -99
# 1079303677                Vip-IRES-Cre   GCaMP6f             -99
# 844199766            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 1093804617                Vip-IRES-Cre   GCaMP6f             -99
# 949480037                 Sst-IRES-Cre   GCaMP6f             -99
# 884756758            Slc17a7-IRES2-Cre   GCaMP6s             -99
# 1065923469                Sst-IRES-Cre   GCaMP6f             -99
# 1099395911                Sst-IRES-Cre   GCaMP6f             -99
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 871808378                                        0.0
# 1086429747                                       1.0
# 864236370                                        1.0
# 1079303677                                       0.0
# 844199766                                        0.0
# 1093804617                                       2.0
# 949480037                                       14.0
# 884756758                                        1.0
# 1065923469                                      13.0
# 1099395911                                      24.0
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 871808378                                      15
# 1086429747                                     20
# 864236370                                     -99
# 1079303677                                      0
# 844199766                                       5
# 1093804617                                      2
# 949480037                                     -99
# 884756758                                       4
# 1065923469                                     20
# 1099395911                                     29
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# behavior_session_id
# 871808378                                     1.0         871526950
# 1086429747                                    0.0               -99
# 864236370                                     0.0               -99
# 1079303677                                    0.0               -99
# 844199766                                     0.0               -99
# 1093804617                                    0.0               -99
# 949480037                                     0.0               -99
# 884756758                                     0.0               -99
# 1065923469                                    0.0               -99
# 1099395911                                    0.0               -99
#
#                                                    ophys_experiment_id  \
# behavior_session_id
# 871808378            [872499144, 872499150, 872499152, 872499154, 8...
# 1086429747                                                         NaN
# 864236370                                                          NaN
# 1079303677                                                         NaN
# 844199766                                                          NaN
# 1093804617                                                         NaN
# 949480037                                                          NaN
# 884756758                                                          NaN
# 1065923469                                                         NaN
# 1099395911                                                         NaN
#
#                                                     ophys_container_id  \
# behavior_session_id
# 871808378            [1018027615, 1018027611, 1018027605, 101802759...
# 1086429747                                                         NaN
# 864236370                                                          NaN
# 1079303677                                                         NaN
# 844199766                                                          NaN
# 1093804617                                                         NaN
# 949480037                                                          NaN
# 884756758                                                          NaN
# 1065923469                                                         NaN
# 1099395911                                                         NaN
#
#                                  project_code  \
# behavior_session_id
# 871808378            VisualBehaviorMultiscope
# 1086429747                                NaN
# 864236370                                 NaN
# 1079303677                                NaN
# 844199766                                 NaN
# 1093804617                                NaN
# 949480037                                 NaN
# 884756758                                 NaN
# 1065923469                                NaN
# 1099395911                                NaN
#
#                                  date_of_acquisition  \
# behavior_session_id
# 871808378           2019-05-20 09:49:35.681000+00:00
# 1086429747          2021-02-25 12:51:12.264000+00:00
# 864236370           2019-05-07 13:59:41.849000+00:00
# 1079303677          2021-01-28 13:40:59.372000+00:00
# 844199766           2019-04-01 11:59:09.960000+00:00
# 1093804617          2021-04-01 09:05:43.558000+00:00
# 949480037           2019-09-18 15:14:41.597000+00:00
# 884756758           2019-06-11 11:50:02.804000+00:00
# 1065923469          2020-11-24 13:23:46.545000+00:00
# 1099395911          2021-04-27 13:13:50.036000+00:00
#
#                                           session_type       file_id
# behavior_session_id
# 871808378                             OPHYS_3_images_A           NaN
# 1086429747                OPHYS_0_images_G_habituation  1.120013e+09
# 864236370                          TRAINING_1_gratings  1.085367e+09
# 1079303677             TRAINING_3_images_G_10uL_reward  1.081804e+09
# 844199766            TRAINING_5_images_A_handoff_ready  1.081592e+09
# 1093804617             TRAINING_3_images_G_10uL_reward  1.120015e+09
# 949480037                          TRAINING_1_gratings  1.085374e+09
# 884756758                 TRAINING_4_images_A_training  1.081630e+09
# 1065923469           TRAINING_5_images_A_handoff_ready  1.120011e+09
# 1099395911           TRAINING_5_images_G_handoff_ready  1.120014e+09

# %% [markdown]
# ## Select one mouse
# We'll choose one mouse id from the full list of unique mouse IDs in the dataset

# %%
mouse_id = behavior_session_table['mouse_id'].unique()[76]
mouse_id
# Out:
# '440298'

# %% [markdown]
# ## query the full behavior sessions table for all sessions that this mouse performed
# This will return a subset of the full `behavior_session_table` in which the mouse_id matches our `mouse_id` variable (mouse 445002). The table should be returned in order of date of acquisition, but we'll use the Pandas command `sort_values(by = 'date_of_acquisition')` just to be sure.
#
# What we then see is a table that has metadata for every session performed by this mouse, in sequential order. The `equipment_name` column tells us where the session was run on that day and the `session_type` column tells us the name of the session type. See the technical white paper for a description of the progression of stages.
#
# For this mouse, we can see that it progressed through a series of training stages starting on 3/15/2019 in behavior training boxes `BEH.B-Box3` and `BEH.B-Box1`.
#
# On 4/1/2019, it reached the `TRAINING_5_images_A_handoff_ready`, which meant that it was ready for transition to an imaging rig as soon as space became available.
#
# On 4/4/2019, it was transitioned to ophys rig `CAM2P.3`, where it then underwent three days of habituation without imaging. This is evidenced by the fact that the session type for 4/4/2019, 4/5/2019, and 4/8/2019 was `OPHYS_0_images_A_habituation` and there was no associated `ophys_session_id`.
#
# The first day of imaging for this mouse was on 4/9/2019, with `session_type = OPHYS_1_images_A`.
#
# Note that this mouse has two `OPHYS_5_images_B_passive` sessions, the first taken in order (immediately after `OPHYS_4_images_B`), and second taken at the end of the sequence. The first `OPHYS_5_images_B_passive` does not have an `ophys_session_id` associated with it. This is likely due to that first session failing to meet quality control standards and being excluded from the dataset. The second `OPHYS_5_images_B_passive` was likely a retake, taken after the first was identified as having been failed.
#
# In general, ophys behavior sessions that do not have associated ophys_session_ids are sessions for which the ophys data has been removed do to failure to meet quality control standards.

# %%
this_mouse_table = behavior_session_table.query('mouse_id == @mouse_id').sort_values(by = 'date_of_acquisition')
# note that the following is functionally equivalent if you find the syntax easier to read: 
# this_mouse_table = behavior_session_table[behavior_session_table['mouse_id'] == mouse_id]
this_mouse_table
# Out:
#                     equipment_name  \
# behavior_session_id
# 831129394                    BEH.F
# 832021447                    BEH.F
# 832544149                    BEH.F
# 833328750                    BEH.F
# 834087859                    BEH.F
# 834903060                    BEH.F
# 835557296                    BEH.F
# 836166694                    BEH.F
# 836761653                    BEH.F
# 837192567               BEH.F-Box5
# 837638916               BEH.F-Box5
# 838496126               BEH.F-Box5
# 839234289               BEH.F-Box5
# 839566045               BEH.F-Box5
# 839939986               BEH.F-Box5
# 840594514               BEH.F-Box5
# 841148118                  CAM2P.3
# 841707177                  CAM2P.3
# 842174399                  CAM2P.3
# 842729895                  CAM2P.3
# 843203333                  CAM2P.3
# 844164376                  CAM2P.3
# 844849972                  CAM2P.3
# 845441512                  CAM2P.3
# 846194950                  CAM2P.3
# 846929750                  CAM2P.3
# 848503804                  CAM2P.3
# 853526948                  CAM2P.3
#
#                                                          full_genotype  \
# behavior_session_id
# 831129394            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 832021447            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 832544149            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 833328750            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 834087859            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 834903060            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 835557296            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 836166694            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 836761653            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 837192567            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 837638916            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 838496126            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839234289            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839566045            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 839939986            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 840594514            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 841148118            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 841707177            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 842174399            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 842729895            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 843203333            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 844164376            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 844849972            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 845441512            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 846194950            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 846929750            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 848503804            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 853526948            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
#
#                     mouse_id       reporter_line  \
# behavior_session_id
# 831129394             440298  Ai93(TITL-GCaMP6f)
# 832021447             440298  Ai93(TITL-GCaMP6f)
# 832544149             440298  Ai93(TITL-GCaMP6f)
# 833328750             440298  Ai93(TITL-GCaMP6f)
# 834087859             440298  Ai93(TITL-GCaMP6f)
# 834903060             440298  Ai93(TITL-GCaMP6f)
# 835557296             440298  Ai93(TITL-GCaMP6f)
# 836166694             440298  Ai93(TITL-GCaMP6f)
# 836761653             440298  Ai93(TITL-GCaMP6f)
# 837192567             440298  Ai93(TITL-GCaMP6f)
# 837638916             440298  Ai93(TITL-GCaMP6f)
# 838496126             440298  Ai93(TITL-GCaMP6f)
# 839234289             440298  Ai93(TITL-GCaMP6f)
# 839566045             440298  Ai93(TITL-GCaMP6f)
# 839939986             440298  Ai93(TITL-GCaMP6f)
# 840594514             440298  Ai93(TITL-GCaMP6f)
# 841148118             440298  Ai93(TITL-GCaMP6f)
# 841707177             440298  Ai93(TITL-GCaMP6f)
# 842174399             440298  Ai93(TITL-GCaMP6f)
# 842729895             440298  Ai93(TITL-GCaMP6f)
# 843203333             440298  Ai93(TITL-GCaMP6f)
# 844164376             440298  Ai93(TITL-GCaMP6f)
# 844849972             440298  Ai93(TITL-GCaMP6f)
# 845441512             440298  Ai93(TITL-GCaMP6f)
# 846194950             440298  Ai93(TITL-GCaMP6f)
# 846929750             440298  Ai93(TITL-GCaMP6f)
# 848503804             440298  Ai93(TITL-GCaMP6f)
# 853526948             440298  Ai93(TITL-GCaMP6f)
#
#                                          driver_line sex  age_in_days  \
# behavior_session_id
# 831129394            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         81.0
# 832021447            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         84.0
# 832544149            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         85.0
# 833328750            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         86.0
# 834087859            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         87.0
# 834903060            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         88.0
# 835557296            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         91.0
# 836166694            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         92.0
# 836761653            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         93.0
# 837192567            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         94.0
# 837638916            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         95.0
# 838496126            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         98.0
# 839234289            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         99.0
# 839566045            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        100.0
# 839939986            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        101.0
# 840594514            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        102.0
# 841148118            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        105.0
# 841707177            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        106.0
# 842174399            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        107.0
# 842729895            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        108.0
# 843203333            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        109.0
# 844164376            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        112.0
# 844849972            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        113.0
# 845441512            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        114.0
# 846194950            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        115.0
# 846929750            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        116.0
# 848503804            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        120.0
# 853526948            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M        129.0
#
#                               cre_line indicator  session_number  \
# behavior_session_id
# 831129394            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 832021447            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 832544149            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 833328750            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 834087859            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 834903060            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 835557296            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 836166694            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 836761653            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 837192567            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 837638916            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 838496126            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 839234289            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 839566045            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 839939986            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 840594514            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 841148118            Slc17a7-IRES2-Cre   GCaMP6f               0
# 841707177            Slc17a7-IRES2-Cre   GCaMP6f               0
# 842174399            Slc17a7-IRES2-Cre   GCaMP6f               0
# 842729895            Slc17a7-IRES2-Cre   GCaMP6f               1
# 843203333            Slc17a7-IRES2-Cre   GCaMP6f               2
# 844164376            Slc17a7-IRES2-Cre   GCaMP6f               3
# 844849972            Slc17a7-IRES2-Cre   GCaMP6f               3
# 845441512            Slc17a7-IRES2-Cre   GCaMP6f               4
# 846194950            Slc17a7-IRES2-Cre   GCaMP6f               5
# 846929750            Slc17a7-IRES2-Cre   GCaMP6f               6
# 848503804            Slc17a7-IRES2-Cre   GCaMP6f               5
# 853526948            Slc17a7-IRES2-Cre   GCaMP6f               3
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 831129394                                        0.0
# 832021447                                        0.0
# 832544149                                        1.0
# 833328750                                        2.0
# 834087859                                        3.0
# 834903060                                        0.0
# 835557296                                        1.0
# 836166694                                        0.0
# 836761653                                        1.0
# 837192567                                        2.0
# 837638916                                        0.0
# 838496126                                        0.0
# 839234289                                        0.0
# 839566045                                        1.0
# 839939986                                        2.0
# 840594514                                        3.0
# 841148118                                        0.0
# 841707177                                        1.0
# 842174399                                        2.0
# 842729895                                        0.0
# 843203333                                        0.0
# 844164376                                        0.0
# 844849972                                        1.0
# 845441512                                        0.0
# 846194950                                        0.0
# 846929750                                        0.0
# 848503804                                        1.0
# 853526948                                        2.0
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 831129394                                     -99
# 832021447                                     -99
# 832544149                                     -99
# 833328750                                     -99
# 834087859                                     -99
# 834903060                                     -99
# 835557296                                     -99
# 836166694                                       0
# 836761653                                       1
# 837192567                                       2
# 837638916                                       3
# 838496126                                       4
# 839234289                                       5
# 839566045                                       6
# 839939986                                       7
# 840594514                                       8
# 841148118                                       9
# 841707177                                      10
# 842174399                                      11
# 842729895                                      12
# 843203333                                      13
# 844164376                                      14
# 844849972                                      15
# 845441512                                       0
# 846194950                                       1
# 846929750                                       2
# 848503804                                       3
# 853526948                                      16
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# behavior_session_id
# 831129394                                     0.0               -99
# 832021447                                     0.0               -99
# 832544149                                     0.0               -99
# 833328750                                     0.0               -99
# 834087859                                     0.0               -99
# 834903060                                     0.0               -99
# 835557296                                     0.0               -99
# 836166694                                     0.0               -99
# 836761653                                     0.0               -99
# 837192567                                     0.0               -99
# 837638916                                     0.0               -99
# 838496126                                     0.0               -99
# 839234289                                     0.0               -99
# 839566045                                     0.0               -99
# 839939986                                     0.0               -99
# 840594514                                     0.0               -99
# 841148118                                     0.0               -99
# 841707177                                     0.0               -99
# 842174399                                     0.0               -99
# 842729895                                     0.0         842583486
# 843203333                                     1.0         843049997
# 844164376                                     2.0               -99
# 844849972                                     3.0               -99
# 845441512                                     4.0         845219209
# 846194950                                     5.0               -99
# 846929750                                     6.0         846599329
# 848503804                                     7.0         848264175
# 853526948                                     8.0               -99
#
#                     ophys_experiment_id ophys_container_id    project_code  \
# behavior_session_id
# 831129394                           NaN                NaN             NaN
# 832021447                           NaN                NaN             NaN
# 832544149                           NaN                NaN             NaN
# 833328750                           NaN                NaN             NaN
# 834087859                           NaN                NaN             NaN
# 834903060                           NaN                NaN             NaN
# 835557296                           NaN                NaN             NaN
# 836166694                           NaN                NaN             NaN
# 836761653                           NaN                NaN             NaN
# 837192567                           NaN                NaN             NaN
# 837638916                           NaN                NaN             NaN
# 838496126                           NaN                NaN             NaN
# 839234289                           NaN                NaN             NaN
# 839566045                           NaN                NaN             NaN
# 839939986                           NaN                NaN             NaN
# 840594514                           NaN                NaN             NaN
# 841148118                           NaN                NaN             NaN
# 841707177                           NaN                NaN             NaN
# 842174399                           NaN                NaN             NaN
# 842729895                   [842973730]        [843049827]  VisualBehavior
# 843203333                   [843519218]        [843049827]  VisualBehavior
# 844164376                           NaN                NaN             NaN
# 844849972                           NaN                NaN             NaN
# 845441512                   [848694639]        [843049827]  VisualBehavior
# 846194950                           NaN                NaN             NaN
# 846929750                   [847125577]        [843049827]  VisualBehavior
# 848503804                   [848698709]        [843049827]  VisualBehavior
# 853526948                           NaN                NaN             NaN
#
#                                  date_of_acquisition  \
# behavior_session_id
# 831129394           2019-03-01 13:25:23.766000+00:00
# 832021447           2019-03-04 14:21:34.570000+00:00
# 832544149           2019-03-05 13:52:38.642000+00:00
# 833328750           2019-03-06 14:27:39.035000+00:00
# 834087859           2019-03-07 14:01:17.016000+00:00
# 834903060           2019-03-08 14:38:02.472000+00:00
# 835557296           2019-03-11 12:33:20.147000+00:00
# 836166694           2019-03-12 14:54:22.690000+00:00
# 836761653           2019-03-13 12:53:27.462000+00:00
# 837192567           2019-03-14 12:49:43.211000+00:00
# 837638916           2019-03-15 13:29:50.376000+00:00
# 838496126           2019-03-18 13:05:17.767000+00:00
# 839234289           2019-03-19 13:15:41.106000+00:00
# 839566045           2019-03-20 13:07:21.399000+00:00
# 839939986           2019-03-21 13:10:44.301000+00:00
# 840594514           2019-03-22 13:23:58.465000+00:00
# 841148118           2019-03-25 08:22:19.380000+00:00
# 841707177           2019-03-26 08:21:46.265000+00:00
# 842174399           2019-03-27 09:00:04.195000+00:00
# 842729895           2019-03-28 09:17:59.122000+00:00
# 843203333           2019-03-29 08:58:48.934000+00:00
# 844164376           2019-04-01 10:52:03.251000+00:00
# 844849972           2019-04-02 11:36:52.447000+00:00
# 845441512           2019-04-03 10:15:51.376000+00:00
# 846194950           2019-04-04 11:13:54.409000+00:00
# 846929750           2019-04-05 11:07:22.302000+00:00
# 848503804           2019-04-09 11:30:55.092000+00:00
# 853526948           2019-04-18 09:36:48.583000+00:00
#
#                                               session_type       file_id
# behavior_session_id
# 831129394            TRAINING_0_gratings_autorewards_15min  1.085362e+09
# 832021447                              TRAINING_1_gratings  1.085362e+09
# 832544149                              TRAINING_1_gratings  1.085362e+09
# 833328750                              TRAINING_1_gratings  1.085362e+09
# 834087859                              TRAINING_1_gratings  1.085362e+09
# 834903060                      TRAINING_2_gratings_flashed  1.081585e+09
# 835557296                      TRAINING_2_gratings_flashed  1.081586e+09
# 836166694                  TRAINING_3_images_A_10uL_reward  1.081586e+09
# 836761653                  TRAINING_3_images_A_10uL_reward  1.081587e+09
# 837192567                  TRAINING_3_images_A_10uL_reward  1.081587e+09
# 837638916                     TRAINING_4_images_A_training  1.081587e+09
# 838496126                     TRAINING_5_images_A_epilogue  1.081588e+09
# 839234289                TRAINING_5_images_A_handoff_ready  1.081588e+09
# 839566045                TRAINING_5_images_A_handoff_ready  1.081589e+09
# 839939986                TRAINING_5_images_A_handoff_ready  1.081589e+09
# 840594514                TRAINING_5_images_A_handoff_ready  1.081589e+09
# 841148118                     OPHYS_0_images_A_habituation  1.085362e+09
# 841707177                     OPHYS_0_images_A_habituation  1.085362e+09
# 842174399                     OPHYS_0_images_A_habituation  1.085362e+09
# 842729895                                 OPHYS_1_images_A           NaN
# 843203333                         OPHYS_2_images_A_passive           NaN
# 844164376                                 OPHYS_3_images_A  1.081592e+09
# 844849972                                 OPHYS_3_images_A  1.081592e+09
# 845441512                                 OPHYS_4_images_B           NaN
# 846194950                         OPHYS_5_images_B_passive  1.081593e+09
# 846929750                                 OPHYS_6_images_B           NaN
# 848503804                         OPHYS_5_images_B_passive           NaN
# 853526948                                 OPHYS_3_images_A  1.081598e+09

# %% [markdown]
# ## iterate over all sessions for this mouse, build a `behavior_session_dict` which will have one behavior session object for every session that this mouse performed, with the key being the `behavior_session_id`
# Note that this could take many minutes to complete. For each session in our new table, `this_mouse_table`, we are pulling the behavior session NWB file from AWS, opening it as a BehaviorSession object using the AllenSDK, and also caching a copy of the NWB file in the directory specified above as `output_dir`. When the below cell completes, all behavior sessions for this mouse will be held in memory in the `behavior_session_dict` dictionary.
#
# If you were to re-run this cell a second time, it would access your cached NWB files instead of downloading them from AWS, allowing it to run substantially faster.
#
# It is important to note that we will only be loading the behavior data here, even for sessions that had corresponding imaging data. The `get_behavior_ophys_experiment` method would be used to get behavior *and* ophys data for ophys sessions. See additional sample notebooks for details.

# %%
behavior_session_ids = this_mouse_table.index.values
behavior_session_dict = {}
for behavior_session_id in behavior_session_ids:
    behavior_session_dict[behavior_session_id] = bc.get_behavior_session(behavior_session_id)
# Out:
# behavior_session_831129394.nwb: 100%|████████████████████████████████████████████| 51.7M/51.7M [00:04<00:00, 10.5MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_832021447.nwb: 100%|████████████████████████████████████████████| 66.9M/66.9M [00:06<00:00, 10.3MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_832544149.nwb: 100%|████████████████████████████████████████████| 66.9M/66.9M [00:06<00:00, 9.68MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_833328750.nwb: 100%|████████████████████████████████████████████| 66.8M/66.8M [00:05<00:00, 12.4MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_834087859.nwb: 100%|████████████████████████████████████████████| 66.7M/66.7M [00:04<00:00, 13.5MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_834903060.nwb: 100%|████████████████████████████████████████████| 67.9M/67.9M [00:05<00:00, 13.4MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_835557296.nwb: 100%|████████████████████████████████████████████| 68.0M/68.0M [00:05<00:00, 12.4MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_836166694.nwb: 100%|██████████████████████████████████████████████| 188M/188M [00:12<00:00, 14.7MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_836761653.nwb: 100%|██████████████████████████████████████████████| 188M/188M [00:14<00:00, 13.0MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_837192567.nwb: 100%|██████████████████████████████████████████████| 188M/188M [00:16<00:00, 11.2MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_837638916.nwb: 100%|██████████████████████████████████████████████| 188M/188M [00:16<00:00, 11.6MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_838496126.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:21<00:00, 8.89MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_839234289.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:16<00:00, 11.4MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_839566045.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:14<00:00, 13.4MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_839939986.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:12<00:00, 15.9MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_840594514.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:18<00:00, 10.2MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_841148118.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:17<00:00, 10.9MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_841707177.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:16<00:00, 11.6MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_842174399.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:12<00:00, 15.0MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_ophys_experiment_842973730.nwb: 100%|█████████████████████████████████████| 864M/864M [00:56<00:00, 15.2MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_ophys_experiment_843519218.nwb: 100%|█████████████████████████████████████| 829M/829M [00:39<00:00, 20.8MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_844164376.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:10<00:00, 17.7MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_844849972.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:08<00:00, 22.2MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_ophys_experiment_848694639.nwb: 100%|█████████████████████████████████████| 428M/428M [00:25<00:00, 16.6MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_846194950.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:12<00:00, 15.9MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_ophys_experiment_847125577.nwb: 100%|█████████████████████████████████████| 924M/924M [00:52<00:00, 17.7MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_ophys_experiment_848698709.nwb: 100%|███████████████████████████████████| 1.33G/1.33G [00:59<00:00, 22.3MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# behavior_session_853526948.nwb: 100%|██████████████████████████████████████████████| 193M/193M [00:09<00:00, 19.9MMB/s]
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.6.0 is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))
# C:\Users\marinag\Anaconda3\envs\visual_behavior_sdk\lib\site-packages\hdmf\spec\namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   % (ns['name'], ns['version'], self.__namespaces.get(ns['name'])['version']))

# %% [markdown]
# ## We can view all attributes of the behavior session object
# These are all of the methods and attributes available on the BehaviorSession object. Not all are explored in this notebook.

# %%
behavior_session_id = behavior_session_ids[-1]
behavior_session_dict[behavior_session_id].list_data_attributes_and_methods()
# Out:
# ['behavior_session_id',
#  'eye_tracking',
#  'eye_tracking_rig_geometry',
#  'get_performance_metrics',
#  'get_reward_rate',
#  'get_rolling_performance_df',
#  'licks',
#  'metadata',
#  'raw_running_speed',
#  'rewards',
#  'running_speed',
#  'stimulus_fingerprint_movie_template',
#  'stimulus_presentations',
#  'stimulus_templates',
#  'stimulus_timestamps',
#  'task_parameters',
#  'trials']

# %% [markdown]
# Note that any attribute can be followed by a `?` in a Jupyter Notebook to see the docstring. For example, running the cell below will make a frame appear at the bottom of your browser with the docstring for the `running_speed` attribute.

# %%
behavior_session = behavior_session_dict[behavior_session_id]
behavior_session.running_speed?

# %% [markdown]
# #### here are some basic task parameters
# We can see the session_type, which is `OPHYS_5_images_B_passive` and a number of other task parameters.

# %%
behavior_session_dict[behavior_session_id].task_parameters
# Out:
# {'auto_reward_volume': 0.005,
#  'blank_duration_sec': [0.5, 0.5],
#  'image_set': 'images_A',
#  'n_stimulus_frames': 69674,
#  'omitted_flash_fraction': 0.05,
#  'response_window_sec': [0.15, 0.75],
#  'reward_volume': 0.007,
#  'session_type': 'OPHYS_3_images_A',
#  'stimulus': 'images',
#  'stimulus_distribution': 'geometric',
#  'stimulus_duration_sec': 0.25,
#  'stimulus_name': None,
#  'task': 'change detection'}

# %% [markdown]
# ## Look at some of the attributes of the last 'handoff ready session'
# We can filter the full table to get the last `TRAINING_5_images_A_handoff_ready` session. This would have been the last training session before the animal was subsequently handed off to the imaging team, after which all sessions were performed on a two-photon imaging rig.

# %%
behavior_session_id = this_mouse_table.query('session_type == "TRAINING_5_images_A_handoff_ready"').index[-1]
# note that the following is functionally equivalent if you find the syntax easier to read: 
# behavior_session_id = this_mouse_table[this_mouse_table['session_type'] == "TRAINING_5_images_A_handoff_ready"].index[-1]
dataset = behavior_session_dict[behavior_session_id]

# %% [markdown]
# ### stimuli
# One entry for every distinct stimulus. Includes onset and offset time/frame.

# %%
dataset.stimulus_presentations.head(5)
# Out:
#                            image_index image_name  duration  start_time  \
# stimulus_presentations_id
# 0                                    0      im065  0.250124  299.950758
# 1                                    0      im065  0.250210  300.701224
# 2                                    0      im065  0.250219  301.451832
# 3                                    0      im065  0.250164  302.202335
# 4                                    0      im065  0.250199  302.952841
#
#                              end_time  start_frame  end_frame  is_change  \
# stimulus_presentations_id
# 0                          300.200882      17985.0    18000.0      False
# 1                          300.951433      18030.0    18045.0      False
# 2                          301.702052      18075.0    18090.0      False
# 3                          302.452499      18120.0    18135.0      False
# 4                          303.203040      18165.0    18180.0      False
#
#                            omitted  flashes_since_change
# stimulus_presentations_id
# 0                            False                     0
# 1                            False                     1
# 2                            False                     2
# 3                            False                     3
# 4                            False                     4

# %% [markdown]
# ### licks
# One entry for every detected lick onset time, assigned the time of the corresponding visual stimulus frame.

# %%
dataset.licks.sample(5)
# Out:
#        timestamps   frame
# 175    416.595886   24979
# 3072  3468.447174  207967
# 119    370.848529   22236
# 596    861.078004   51630
# 615    873.252833   52360

# %% [markdown]
# ### rewards
# One entry for every reward that was delivered, assigned the time of the corresponding visual stimulus frame. `Autorewarded` is True if the reward was delivered without requiring a preceding lick.

# %%
dataset.rewards.sample(5)
# Out:
#      volume   timestamps  auto_rewarded
# 133   0.007  3508.924413          False
# 0     0.005   311.325174           True
# 53    0.007  1788.351260          False
# 15    0.007   686.744161          False
# 131   0.007  3487.276475          False

# %% [markdown]
# ### running data
# One entry for each read of the analog input line monitoring the encoder voltage, polled at ~60 Hz

# %%
dataset.running_speed.head()
# Out:
#    timestamps      speed
# 0    0.000000   0.015420
# 1    0.016199   4.072436
# 2    0.032890   7.888294
# 3    0.049588  11.231527
# 4    0.066925  13.908257

# %% [markdown]
# ### we can make a simple plot where we combine together running, licking and stimuli

# %% [markdown]
# #### First, add a column to the stimulus_presentations table that assigns a unique color to every stimulus

# %%
unique_stimuli = [stimulus for stimulus in dataset.stimulus_presentations['image_name'].unique()]
colormap = {image_name: sns.color_palette()[image_number] for image_number, image_name in enumerate(np.sort(unique_stimuli))}
dataset._stimuli._presentations.value['color'] = dataset.stimulus_presentations['image_name'].map(lambda image_name: colormap[image_name])

# %% [markdown]
# #### now make some simple plotting functions to plot these datastreams

# %%
def plot_running(ax, initial_time, final_time):
    '''
    a simple function to plot running speed between two specified times on a specified axis
    inputs:
        ax: axis on which to plot
        intial_time: initial time to plot from
        final_time: final time to plot to
    '''
    running_sample = dataset.running_speed.query('timestamps >= @initial_time and timestamps <= @final_time')
    ax.plot(
        running_sample['timestamps'],
        running_sample['speed']
    )

def plot_licks(ax, initial_time, final_time):
    '''
    a simple function to plot licks as dots between two specified times on a specified axis
    inputs:
        ax: axis on which to plot
        intial_time: initial time to plot from
        final_time: final time to plot to
    '''
    licking_sample = dataset.licks.query('timestamps >= @initial_time and timestamps <= @final_time')
    ax.plot(
        licking_sample['timestamps'],
        np.zeros_like(licking_sample['timestamps']),
        marker = 'o',
        color = 'black',
        linestyle = 'none'
    )
    
def plot_rewards(ax, initial_time, final_time):
    '''
    a simple function to plot rewards between two specified times as blue diamonds on a specified axis
    inputs:
        ax: axis on which to plot
        intial_time: initial time to plot from
        final_time: final time to plot to
    '''
    rewards_sample = dataset.rewards.query('timestamps >= @initial_time and timestamps <= @final_time')
    ax.plot(
        rewards_sample['timestamps'],
        np.zeros_like(rewards_sample['timestamps']),
        marker = 'd',
        color = 'blue',
        linestyle = 'none',
        markersize = 12,
        alpha = 0.5
    )
    
def plot_stimuli(ax, ti, tf):
    '''
    a simple function to plot stimuli as colored vertical spans on a s
    inputs:
        ax: axis on which to plot
        intial_time: initial time to plot from
        final_time: final time to plot to
    '''
    stimulus_presentations_sample = dataset.stimulus_presentations.query('end_time >= @initial_time and start_time <= @final_time')
    for idx, stimulus in stimulus_presentations_sample.iterrows():
        ax.axvspan(stimulus['start_time'], stimulus['end_time'], color=stimulus['color'], alpha=0.25)

# %% [markdown]
# #### now make the plot

# %%
initial_time = 775 # initial time for plot, in seconds
final_time = 800 # final time for plot, in seconds

plt.clf()
fig, ax = plt.subplots(figsize = (15,5))
plot_running(ax, initial_time, final_time)
plot_licks(ax, initial_time, final_time)
plot_rewards(ax, initial_time, final_time)
plot_stimuli(ax, initial_time, final_time)

ax.legend(['running speed', 'licks', 'rewards'])

ax.set_ylabel('running speed (cm/s)')
ax.set_xlabel('time in session (s)')
ax.set_xlim(initial_time, final_time)
ax.set_title('a short section of the session');
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# Above, we can see that stimuli were being delivered at a regular cadence (250 ms on, 500 ms off). There were changes to new stimuli at t = 778.6 and t = 793.7, as indicated by the change in the color of the bars. The mouse licked inside of the required response window following both stimulus changes and received a reward coincident with the first lick following the change. The subsequent licks are likely a result of the mouse consuming the water reward. There was also a brief bout of two licks, likely representing impulsivity, at t = 786.9.

# %% [markdown]
# ### trials
# We can view attributes of every trial here. Below is a random sample of 5 trials

# %%
dataset.trials.sample(5)
# Out:
#             start_time    stop_time  \
# trials_id
# 470        2572.911960  2574.763192
# 276        1568.586896  1569.587576
# 690        3602.954224  3603.371206
# 563        2892.826944  2898.397337
# 370        2068.956539  2076.228093
#
#                                                   lick_times  reward_time  \
# trials_id
# 470        [2573.5290334965102, 2573.745845303638, 2573.8...          NaN
# 276        [1568.9204579230864, 1569.070552758174, 1569.2...          NaN
# 690                                     [3603.0542915955884]          NaN
# 563                  [2897.963749923394, 2898.0804933363106]          NaN
# 370        [2072.69234928675, 2072.992538679857, 2073.092...  2072.692349
#
#            reward_volume    hit  false_alarm   miss  is_change  aborted  \
# trials_id
# 470                0.000  False        False  False      False     True
# 276                0.000  False        False  False      False     True
# 690                0.000  False        False  False      False     True
# 563                0.000  False        False  False      False     True
# 370                0.007   True        False  False       True    False
#
#               go  catch  auto_rewarded  correct_reject  trial_length  \
# trials_id
# 470        False  False          False           False      1.851232
# 276        False  False          False           False      1.000681
# 690        False  False          False           False      0.416982
# 563        False  False          False           False      5.570393
# 370         True  False          False           False      7.271554
#
#            response_time  change_frame  change_time  response_latency  \
# trials_id
# 470                  NaN           NaN          NaN               NaN
# 276                  NaN           NaN          NaN               NaN
# 690                  NaN           NaN          NaN               NaN
# 563                  NaN           NaN          NaN               NaN
# 370          2072.692349      124234.0  2071.979708          0.712641
#
#           initial_image_name change_image_name
# trials_id
# 470                    im069             im069
# 276                    im065             im065
# 690                    im069             im069
# 563                    im077             im077
# 370                    im069             im077

# %% [markdown]
# #### we can examine one trial in some detail. Let's randomly select a hit trial.
# Some things to note:
# * The trial started at 831.2635398912244 seconds (`start_time`) relative to the start of the session.
# * The stimulus changed from 'im063' (`intial_image_name`) to 'im069' (`change_image_name`) at t = 834.287206646593 seconds (`change_time`) relative to the start of the session.
# * The animal's first lick (`lick_times[0]`) and `response_time` was at t = 834.69975263 seconds relative to the start of the session.
# * The `response_latency`, which is `response_time` - `change_time`, was 0.41254598174464263 seconds.
# * A reward (`reward_time`) was delivered at 834.6997526283376 seconds relative to the start of the session. This was coincident with the first lick.

# %%
dataset.trials.query('hit').sample(random_state=0).to_dict('records')
# Out:
# [{'start_time': 1712.116697982885,
#   'stop_time': 1720.1720967957517,
#   'lick_times': array([1716.53632556, 1716.61971894, 1716.86988826, 1716.98660287,
#          1717.10337204, 1717.23680377, 1717.37018203, 1717.47025015,
#          1717.6036877 , 1717.73710363, 1718.02067646, 1718.17075606]),
#   'reward_time': 1716.5363255622797,
#   'reward_volume': 0.007,
#   'hit': True,
#   'false_alarm': False,
#   'miss': False,
#   'is_change': True,
#   'aborted': False,
#   'go': True,
#   'catch': False,
#   'auto_rewarded': False,
#   'correct_reject': False,
#   'trial_length': 8.05539881286677,
#   'response_time': 1716.5363255622797,
#   'change_frame': 102884.0,
#   'change_time': 1715.9070473431634,
#   'response_latency': 0.6292782191162587,
#   'initial_image_name': 'im061',
#   'change_image_name': 'im077'}]

# %% [markdown]
# ## One useful method is the `get_performance_metrics` method, which returns some summary metrics on the session, derived from the 'rolling_performance_df'

# %%
behavior_session_dict[behavior_session_id].get_performance_metrics()
# Out:
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\scipy\stats\_distn_infrastructure.py:2122: RuntimeWarning: invalid value encountered in greater
#   cond1 = (0 < q) & (q < 1)
# C:\Users\marinag\AppData\Roaming\Python\Python37\site-packages\scipy\stats\_distn_infrastructure.py:2122: RuntimeWarning: invalid value encountered in less
#   cond1 = (0 < q) & (q < 1)
# {'trial_count': 731,
#  'go_trial_count': 182,
#  'catch_trial_count': 23,
#  'hit_trial_count': 140,
#  'miss_trial_count': 42,
#  'false_alarm_trial_count': 9,
#  'correct_reject_trial_count': 14,
#  'auto_reward_count': 5,
#  'earned_reward_count': 140,
#  'total_reward_count': 145,
#  'total_reward_volume': 1.005,
#  'maximum_reward_rate': 4.075808888375142,
#  'engaged_trial_count': 592,
#  'mean_hit_rate': 0.8502914507732704,
#  'mean_hit_rate_uncorrected': 0.8566154925851169,
#  'mean_hit_rate_engaged': 0.8501338035208221,
#  'mean_false_alarm_rate': 0.4443704962837621,
#  'mean_false_alarm_rate_uncorrected': 0.4367174350592722,
#  'mean_false_alarm_rate_engaged': 0.44609689480379144,
#  'mean_dprime': 1.1971098252194952,
#  'mean_dprime_engaged': 1.193310233405481,
#  'max_dprime': 1.7904646832340632,
#  'max_dprime_engaged': 1.5810766796714655}

# %% [markdown]
# ## we can build out a new table that has all performance data for every session as follows:
# This might take a minute or so. The AllenSDK will be extracting the performance data from the NWB file for every session individually.

# %%
behavior_performance_table = pd.DataFrame(
    [behavior_session_dict[behavior_session_id].get_performance_metrics() for behavior_session_id in behavior_session_ids]
).set_index(behavior_session_ids)

# %%
behavior_performance_table.head()
# Out:
#            trial_count  go_trial_count  catch_trial_count  hit_trial_count  \
# 831129394          122               0                  0                0
# 832021447         1609             101                 17               67
# 832544149         1581              76                 13               75
# 833328750         1158             189                 21              140
# 834087859          565             294                 53              124
#
#            miss_trial_count  false_alarm_trial_count  \
# 831129394                 0                        0
# 832021447                34                       10
# 832544149                 1                        9
# 833328750                49                        7
# 834087859               170                        7
#
#            correct_reject_trial_count  auto_reward_count  earned_reward_count  \
# 831129394                           0                122                    0
# 832021447                           7                  6                   67
# 832544149                           4                  5                   75
# 833328750                          14                  7                  140
# 834087859                          46                 17                  124
#
#            total_reward_count  total_reward_volume  maximum_reward_rate  \
# 831129394                 122                0.610             7.940230
# 832021447                  73                0.700             3.003025
# 832544149                  80                0.775             4.100249
# 833328750                 147                1.435             4.914088
# 834087859                 141                1.325             5.402127
#
#            engaged_trial_count  mean_hit_rate  mean_hit_rate_uncorrected  \
# 831129394                  112            NaN                        NaN
# 832021447                  172       0.438318                   0.427423
# 832544149                  388       0.957304                   0.974269
# 833328750                  664       0.870796                   0.881694
# 834087859                  322       0.531782                   0.539226
#
#            mean_hit_rate_engaged  mean_false_alarm_rate  \
# 831129394                    NaN                    NaN
# 832021447               0.433100               0.421818
# 832544149               0.974991               0.787584
# 833328750               0.935623               0.502420
# 834087859               0.832751               0.197336
#
#            mean_false_alarm_rate_uncorrected  mean_false_alarm_rate_engaged  \
# 831129394                                NaN                            NaN
# 832021447                           0.397976                       0.435379
# 832544149                           0.881553                       0.805444
# 833328750                           0.482349                       0.633119
# 834087859                           0.165555                       0.301101
#
#            mean_dprime  mean_dprime_engaged  max_dprime  max_dprime_engaged
# 831129394          NaN                  NaN         NaN                 NaN
# 832021447     0.121475            -0.006137    0.792775            0.131320
# 832544149     1.093624             1.089942    1.857055            1.857055
# 833328750     1.485135             1.364075    2.217040            2.104946
# 834087859     1.129222             1.766182    2.850748            2.850748

# %% [markdown]
# ## for convenience, we should merge this with the existing table we built for this mouse

# %%
this_mouse_table = this_mouse_table.merge(
    behavior_performance_table,
    left_index = True,
    right_index = True,
)
this_mouse_table.head()
# Out:
#                     equipment_name  \
# behavior_session_id
# 831129394                    BEH.F
# 832021447                    BEH.F
# 832544149                    BEH.F
# 833328750                    BEH.F
# 834087859                    BEH.F
#
#                                                          full_genotype  \
# behavior_session_id
# 831129394            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 832021447            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 832544149            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 833328750            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 834087859            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
#
#                     mouse_id       reporter_line  \
# behavior_session_id
# 831129394             440298  Ai93(TITL-GCaMP6f)
# 832021447             440298  Ai93(TITL-GCaMP6f)
# 832544149             440298  Ai93(TITL-GCaMP6f)
# 833328750             440298  Ai93(TITL-GCaMP6f)
# 834087859             440298  Ai93(TITL-GCaMP6f)
#
#                                          driver_line sex  age_in_days  \
# behavior_session_id
# 831129394            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         81.0
# 832021447            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         84.0
# 832544149            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         85.0
# 833328750            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         86.0
# 834087859            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         87.0
#
#                               cre_line indicator  session_number  \
# behavior_session_id
# 831129394            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 832021447            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 832544149            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 833328750            Slc17a7-IRES2-Cre   GCaMP6f             -99
# 834087859            Slc17a7-IRES2-Cre   GCaMP6f             -99
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 831129394                                        0.0
# 832021447                                        0.0
# 832544149                                        1.0
# 833328750                                        2.0
# 834087859                                        3.0
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 831129394                                     -99
# 832021447                                     -99
# 832544149                                     -99
# 833328750                                     -99
# 834087859                                     -99
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# behavior_session_id
# 831129394                                     0.0               -99
# 832021447                                     0.0               -99
# 832544149                                     0.0               -99
# 833328750                                     0.0               -99
# 834087859                                     0.0               -99
#
#                     ophys_experiment_id ophys_container_id project_code  \
# behavior_session_id
# 831129394                           NaN                NaN          NaN
# 832021447                           NaN                NaN          NaN
# 832544149                           NaN                NaN          NaN
# 833328750                           NaN                NaN          NaN
# 834087859                           NaN                NaN          NaN
#
#                                  date_of_acquisition  \
# behavior_session_id
# 831129394           2019-03-01 13:25:23.766000+00:00
# 832021447           2019-03-04 14:21:34.570000+00:00
# 832544149           2019-03-05 13:52:38.642000+00:00
# 833328750           2019-03-06 14:27:39.035000+00:00
# 834087859           2019-03-07 14:01:17.016000+00:00
#
#                                               session_type       file_id  \
# behavior_session_id
# 831129394            TRAINING_0_gratings_autorewards_15min  1.085362e+09
# 832021447                              TRAINING_1_gratings  1.085362e+09
# 832544149                              TRAINING_1_gratings  1.085362e+09
# 833328750                              TRAINING_1_gratings  1.085362e+09
# 834087859                              TRAINING_1_gratings  1.085362e+09
#
#                      trial_count  go_trial_count  catch_trial_count  \
# behavior_session_id
# 831129394                    122               0                  0
# 832021447                   1609             101                 17
# 832544149                   1581              76                 13
# 833328750                   1158             189                 21
# 834087859                    565             294                 53
#
#                      hit_trial_count  miss_trial_count  \
# behavior_session_id
# 831129394                          0                 0
# 832021447                         67                34
# 832544149                         75                 1
# 833328750                        140                49
# 834087859                        124               170
#
#                      false_alarm_trial_count  correct_reject_trial_count  \
# behavior_session_id
# 831129394                                  0                           0
# 832021447                                 10                           7
# 832544149                                  9                           4
# 833328750                                  7                          14
# 834087859                                  7                          46
#
#                      auto_reward_count  earned_reward_count  \
# behavior_session_id
# 831129394                          122                    0
# 832021447                            6                   67
# 832544149                            5                   75
# 833328750                            7                  140
# 834087859                           17                  124
#
#                      total_reward_count  total_reward_volume  \
# behavior_session_id
# 831129394                           122                0.610
# 832021447                            73                0.700
# 832544149                            80                0.775
# 833328750                           147                1.435
# 834087859                           141                1.325
#
#                      maximum_reward_rate  engaged_trial_count  mean_hit_rate  \
# behavior_session_id
# 831129394                       7.940230                  112            NaN
# 832021447                       3.003025                  172       0.438318
# 832544149                       4.100249                  388       0.957304
# 833328750                       4.914088                  664       0.870796
# 834087859                       5.402127                  322       0.531782
#
#                      mean_hit_rate_uncorrected  mean_hit_rate_engaged  \
# behavior_session_id
# 831129394                                  NaN                    NaN
# 832021447                             0.427423               0.433100
# 832544149                             0.974269               0.974991
# 833328750                             0.881694               0.935623
# 834087859                             0.539226               0.832751
#
#                      mean_false_alarm_rate  mean_false_alarm_rate_uncorrected  \
# behavior_session_id
# 831129394                              NaN                                NaN
# 832021447                         0.421818                           0.397976
# 832544149                         0.787584                           0.881553
# 833328750                         0.502420                           0.482349
# 834087859                         0.197336                           0.165555
#
#                      mean_false_alarm_rate_engaged  mean_dprime  \
# behavior_session_id
# 831129394                                      NaN          NaN
# 832021447                                 0.435379     0.121475
# 832544149                                 0.805444     1.093624
# 833328750                                 0.633119     1.485135
# 834087859                                 0.301101     1.129222
#
#                      mean_dprime_engaged  max_dprime  max_dprime_engaged
# behavior_session_id
# 831129394                            NaN         NaN                 NaN
# 832021447                      -0.006137    0.792775            0.131320
# 832544149                       1.089942    1.857055            1.857055
# 833328750                       1.364075    2.217040            2.104946
# 834087859                       1.766182    2.850748            2.850748

# %% [markdown]
# ## Now we can plot the `max_dprime` value for every session
# We can see that this particular mouse performed relatively consistently for every session as it progressed through training.

# %%
fig, ax = plt.subplots(figsize = (15,5))

ax.plot(
    np.arange(len(this_mouse_table)),
    this_mouse_table['max_dprime'],
    marker = 'o'
)
ax.set_xticks(range(len(this_mouse_table)))
ax.set_xticklabels(list(this_mouse_table['session_type'].values),rotation = 30, ha='right')

# make alternating black/gray vspans for visual clarity
colors = ['black', 'gray']
for ii in range(len(this_mouse_table)):
    ax.axvspan(ii - 0.5, ii + 0.5, color = colors[ii%2], alpha=0.25)

ax.set_xlim(-0.5, len(this_mouse_table) - 0.5)
ax.set_ylabel('dprime')
ax.set_xlabel('session type')
ax.set_title("Max of rolling d' for every session for mouse {}".format(mouse_id))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1500">
